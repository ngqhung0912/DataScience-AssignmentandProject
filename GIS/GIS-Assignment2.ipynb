# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
data_overijssel = gpd.read_file('Datasets/overijssel-latest-free.shp/gis_osm_places_free_1.shp')

# %%
data_overijssel
# Out:
#          osm_id  code    fclass  population            name  \
# 0      45368602  1050  locality           0      Ter Huurne
# 1      45371477  1004    hamlet           0         Harmole
# 2      45412644  1004    hamlet           0       Den Braam
# 3      45497536  1004    hamlet           0        Brammelo
# 4      45551604  1004    hamlet           0     Nettelhorst
# ..          ...   ...       ...         ...             ...
# 560  9196092243  1004    hamlet           0     't Evenbelt
# 561  9196260001  1003   village         145   Witte Paarden
# 562  9196307122  1003   village         660  's-Heerenbroek
# 563  9547360191  1004    hamlet           0        Veldhoek
# 564  9600113754  1010    suburb       28280      Colmschate
#
#                      geometry
# 0    POINT (6.86817 52.12839)
# 1    POINT (6.84989 52.12854)
# 2    POINT (6.85126 52.13752)
# 3    POINT (6.67846 52.15576)
# 4    POINT (6.47516 52.16966)
# ..                        ...
# ...

# %%
data_overijssel.plot()
# Out:
# <Axes: >

# %%
data_overijssel_railway = gpd.read_file('Datasets/overijssel-latest-free.shp/gis_osm_railways_free_1.shp')

# %%
data_overijssel_railway.plot()
# Out:
# <Axes: >

# %%
figure, axis = plt.subplots(1, 1)

data_overijssel.plot(ax=axis,c='b')
data_overijssel_railway.plot(ax=axis,color='r', linewidth=2)
# Out:
# <Axes: >
